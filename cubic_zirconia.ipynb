# %% [markdown]
# ### Data Description

# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings("ignore")

# %%
# Loading the dataset

df = pd.read_csv('D:\\Internshala\\cubic_zirconia.csv')

# %%
# Checking the top 10 rows

df.head(10)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
# 5           6   1.02      Ideal     D     VS2   61.5   56.0  6.46  6.49  3.99
# 6           7   1.01       Good     H     SI1   63.7   60.0  6.35  6.30  4.03
# 7           8   0.50    Premium     E     SI1   61.5   62.0  5.09  5.06  3.12
# 8           9   1.21       Good     H     SI1   63.8   64.0  6.72  6.63  4.26
# 9          10   0.35      Ideal     F     VS2   60.5   57.0  4.52  4.60  2.76
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779
# 5   9502
# 6   4836
# 7   1415
# 8   5407
# ...

# %%
# Checking the last 10 rows

df.tail(10)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 26957       26958   2.09    Premium     H     SI2   60.6   59.0  8.27  8.22
# 26958       26959   1.37    Premium     E     SI2   61.0   57.0  7.25  7.19
# 26959       26960   1.05  Very Good     E     SI2   63.2   59.0  6.43  6.36
# 26960       26961   1.10  Very Good     D     SI2    NaN   63.0  6.76  6.69
# 26961       26962   0.25    Premium     F    VVS2   62.0   59.0  4.04  3.99
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 26957  5.00  17805
# 26958  4.40   6751
# 26959  4.04   4281
# 26960  3.94   4361
# 26961  2.49    740
# ...

# %%
# No. of rows and columns in the dataset

df.shape
# Out:
# (26967, 11)

# %%
# Checking the data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26270 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
# 5-point summary of the dataset

df.describe()
# Out:
#          Unnamed: 0         carat         depth         table             x  \
# count  26967.000000  26967.000000  26270.000000  26967.000000  26967.000000
# mean   13484.000000      0.798375     61.745147     57.456080      5.729854
# std     7784.846691      0.477745      1.412860      2.232068      1.128516
# min        1.000000      0.200000     50.800000     49.000000      0.000000
# 25%     6742.500000      0.400000     61.000000     56.000000      4.710000
# 50%    13484.000000      0.700000     61.800000     57.000000      5.690000
# 75%    20225.500000      1.050000     62.500000     59.000000      6.550000
# max    26967.000000      4.500000     73.600000     79.000000     10.230000
#
#                   y             z         price
# count  26967.000000  26967.000000  26967.000000
# mean       5.733569      3.538057   3939.518115
# std        1.166058      0.720624   4024.864666
# min        0.000000      0.000000    326.000000
# ...

# %%
# Checking for duplicates in the dataset

print('No. of duplicates =', df.duplicated().sum())
# Out:
# No. of duplicates = 0

# %%
# Checking for missing values

df.isnull().sum()
# Out:
# Unnamed: 0      0
# carat           0
# cut             0
# color           0
# clarity         0
# depth         697
# table           0
# x               0
# y               0
# z               0
# price           0
# dtype: int64

# %% [markdown]
# #### Insight 1:

# %%
# The dataset consists of  26967 rows and 11 columns.

# The dataset consists of 2 integer, 3 object and 6 float type variables.
    # Categorical : cut, color and clarity
    # Continuous: carat, depth, table, x, y, z and price
    # Price is the target variable.
    
# There are no duplicates in the given dataset.

# In total, there are 697 missing values in the dataset, which comes under the column depth.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ### Missing value treament

# %%
Null_value_percent = df.isnull().sum() * 100 / len(df)
Null_value_percent
# Out:
# Unnamed: 0    0.00000
# carat         0.00000
# cut           0.00000
# color         0.00000
# clarity       0.00000
# depth         2.58464
# table         0.00000
# x             0.00000
# y             0.00000
# z             0.00000
# price         0.00000
# dtype: float64

# %%
df.depth = df.depth.fillna(df['depth'].median(), inplace = False)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# x             0
# y             0
# z             0
# price         0
# dtype: int64

# %% [markdown]
# #### Insight 2:

# %%
# Null values affect the performance and accuracy of any machine learning algorithm. So it is important to remove them from the dataset before applying any machine learning algorithm.
# Since the depth column (numerical variable) has only 2.5% of missing or null value, we can impute with its median value.

# %% [markdown]
# ### Ouliers Treatment

# %%
plt.figure(figsize=(15,8))
df.boxplot();

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
lr,ur=remove_outlier(df["carat"])
df["carat"]=np.where(df["carat"]>ur,ur,df["carat"])
df["carat"]=np.where(df["carat"]<lr,lr,df["carat"])

# %%
lr,ur=remove_outlier(df["depth"])
df["depth"]=np.where(df["depth"]>ur,ur,df["depth"])
df["depth"]=np.where(df["depth"]<lr,lr,df["depth"])

# %%
lr,ur=remove_outlier(df["table"])
df["table"]=np.where(df["table"]>ur,ur,df["table"])
df["table"]=np.where(df["table"]<lr,lr,df["table"])

# %%
lr,ur=remove_outlier(df["x"])
df["x"]=np.where(df["x"]>ur,ur,df["x"])
df["x"]=np.where(df["x"]<lr,lr,df["x"])

# %%
lr,ur=remove_outlier(df["y"])
df["y"]=np.where(df["y"]>ur,ur,df["y"])
df["y"]=np.where(df["y"]<lr,lr,df["y"])

# %%
lr,ur=remove_outlier(df["z"])
df["z"]=np.where(df["z"]>ur,ur,df["z"])
df["z"]=np.where(df["z"]<lr,lr,df["z"])

# %%
lr,ur=remove_outlier(df["price"])
df["price"]=np.where(df["price"]>ur,ur,df["price"])
df["price"]=np.where(df["price"]<lr,lr,df["price"])

# %%
plt.figure(figsize=(15,8))
df.boxplot();

# %% [markdown]
# #### Insight 3:

# %%
# Outliers represent measurement errors and data entry, which can result in misleading interpretations.
# They are almost present in all the columns.
# We have removed the outliers by doing capping/flooring method.

# %% [markdown]
# ### Data Preprocessing

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x',
#        'y', 'z', 'price'],
#       dtype='object')

# %%
df[['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x',
       'y', 'z', 'price']].nunique()
# Out:
# Unnamed: 0    26967
# carat           183
# cut               5
# color             7
# clarity           8
# depth            57
# table            99
# x               521
# y               517
# z               344
# price          7282
# dtype: int64

# %%
df.cut.value_counts()
# Out:
# Ideal        10816
# Premium       6899
# Very Good     6030
# Good          2441
# Fair           781
# Name: cut, dtype: int64

# %%
df.color.value_counts()
# Out:
# G    5661
# E    4917
# F    4729
# H    4102
# D    3344
# I    2771
# J    1443
# Name: color, dtype: int64

# %%
df.clarity.value_counts()
# Out:
# SI1     6571
# VS2     6099
# SI2     4575
# VS1     4093
# VVS2    2531
# VVS1    1839
# IF       894
# I1       365
# Name: clarity, dtype: int64

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z   price
# 0   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66   499.0
# 1   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70   984.0
# 2   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78  6289.0
# 3   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96  1082.0
# 4   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65   779.0

# %% [markdown]
# #### Insight 4:

# %%
# In cut, the increasing order of quality is Fair, Good, Very Good, Premium, Ideal
# In color, D being the best color and J the worst color
# In clarity, the order from best to worst is IF, VVS1, VVS2, VS1, VS2, SI1, SI2, I1
# The column Unnamed: 0 is dropped, which is irrelevant for further analysis

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Univariate Analysis

# %%
fig, axes = plt.subplots(nrows=7,ncols=2)
fig.set_size_inches(15, 20)

a = sns.distplot(df['carat'] , ax=axes[0][0])
a.set_title("carat Distribution",fontsize=15)

a = sns.boxplot(df['carat'] , orient = "v" , ax=axes[0][1])
a.set_title("carat Distribution",fontsize=15)

fig.tight_layout(pad=3.0)

a = sns.distplot(df['depth'] , ax=axes[1][0])
a.set_title("depth Distribution",fontsize=15)

a = sns.boxplot(df['depth'] , orient = "v" , ax=axes[1][1])
a.set_title("depth Distribution",fontsize=15)
/
a = sns.distplot(df['table'] , ax=axes[2][0])
a.set_title("table Distribution",fontsize=15)

a = sns.boxplot(df['table'] , orient = "v" , ax=axes[2][1])
a.set_title("table Distribution",fontsize=15)

a = sns.distplot(df['x'] , ax=axes[3][0])
a.set_title("x Distribution",fontsize=15)

a = sns.boxplot(df['x'] , orient = "v" , ax=axes[3][1])
a.set_title("x Distribution",fontsize=15)

a = sns.distplot(df['y'] , ax=axes[4][0])
a.set_title("y Distribution",fontsize=15)

a = sns.boxplot(df['y'] , orient = "v" , ax=axes[4][1])
a.set_title("y Distribution",fontsize=15)

a = sns.distplot(df['z'] , ax=axes[5][0])
a.set_title("z Distribution",fontsize=15)

a = sns.boxplot(df['z'] , orient = "v" , ax=axes[5][1])
a.set_title("z Distribution",fontsize=15)

a = sns.distplot(df['price'] , ax=axes[6][0])
a.set_title("price Distribution",fontsize=15)

a = sns.boxplot(df['price'] , orient = "v" , ax=axes[6][1])
a.set_title("price Distribution",fontsize=15);

# %% [markdown]
# #### Insight 5:

# %%
# The distribution of carat seems to be positively skewed as there are multiple peaks points in the distribution. Data lies in the range of 0.25 to 2.
# The distribution of depth seems to be normal distribution. Data lies in the range of 59 to 65.
# The distribution of table seems to be positively skewed. Data lies in the range of 51 to 63.
# The distribution of x is positively skewed. The data distribution ranges from 2 to 10.
# The distribution of y is positively skewed. The data distribution ranges from 2 to 10.
# The distribution of z is positively skewed. The data distribution ranges from 1 to 6.
# The target variable, price, seems to be positively skewed. The price column ranges from 500 to 12000.

# %% [markdown]
# ### Bivariate Analysis

# %%
fig, axes = plt.subplots(nrows=3,ncols=2)
fig.set_size_inches(15, 20)


a = sns.countplot(x="cut", data=df , ax=axes[0][0])
a.set_title("cut - countplot",fontsize=15)
a = sns.barplot(x='cut', y='price', data=df, orient = "v" , ax=axes[0][1])
a.set_title("cut - barplot",fontsize=15)

a = sns.countplot(x="color", data=df , ax=axes[1][0])
a.set_title("color - countplot",fontsize=15)
a = sns.barplot(x='color', y='price', data=df, orient = "v" , ax=axes[1][1])
a.set_title("color - barplot",fontsize=15)

a = sns.countplot(x="clarity", data=df , ax=axes[2][0])
a.set_title("clarity - countplot",fontsize=15)
a = sns.barplot(x='clarity', y='price', data=df, orient = "v" , ax=axes[2][1])
a.set_title("clarity - barplot",fontsize=15);

# %% [markdown]
# #### Insight 6:

# %%
# cut
# From the countplot, Ideal cut has the highest count and Fair has the lowest count
# From the boxplot, in terms of price, stones with Ideal cuts are the lowest because Ideal cuts are highly priced hence it's least preferred one. Whereas Fair cuts are highly preferred, hence it is the highest.

# color
# From the countplot, G has the highest count and J has the lowest count
# From the boxplot, in terms of price, the worst color J is highly preferred because of it's low price. Whereas D and E are least preferred, since they're highly priced.

# clarity
# From the countplot, SI1 has the highest count and I1 has the lowest count
# From the boxplot, in terms of price, SI2 highly preferred because of it's low price. Whereas VVS1 is least preferred, since it is highly priced.

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df);

# %% [markdown]
# #### Correlation

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True,fmt=".2f");
plt.show()

# %% [markdown]
# #### Insight 7:

# %%
# The heatmap is used to visualize the strength of correlation among variables.
# It is clear from the heatmap that almost all the columns are highly correlated with the price of stone, except for the depth column.
# It is considered as negative correlation, when one variable gets bigger, the other variable tends to get smaller.
